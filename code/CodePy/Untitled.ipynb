# %%
import collections
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.karate_club_graph()

# %%
nx.draw_networkx(G)
plt.show()
# Out:
# C:\Users\moer\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
cliques = list(nx.find_cliques(G, K))

# %%
for i, c in enumerate(cliques):
    print(i, c)
# Out:
# 0 [0, 1, 17]
# 1 [0, 1, 2, 3, 13]
# 2 [0, 1, 2, 3, 7]
# 3 [0, 1, 19]
# 4 [0, 1, 21]
# 5 [0, 4, 10]
# 6 [0, 4, 6]
# 7 [0, 5, 10]
# 8 [0, 5, 6]
# 9 [0, 8, 2]
# 10 [0, 11]
# 11 [0, 12, 3]
# 12 [0, 31]
# 13 [1, 30]
# 14 [2, 32, 8]
# 15 [2, 9]
# 16 [2, 27]
# 17 [2, 28]
# 18 [5, 16, 6]
# 19 [33, 32, 8, 30]
# 20 [33, 32, 14]
# 21 [33, 32, 15]
# 22 [33, 32, 18]
# 23 [33, 32, 20]
# 24 [33, 32, 22]
# 25 [33, 32, 23, 29]
# 26 [33, 32, 31]
# 27 [33, 9]
# 28 [33, 13]
# 29 [33, 19]
# 30 [33, 26, 29]
# 31 [33, 27, 23]
# 32 [33, 28, 31]
# 33 [24, 25, 31]
# 34 [24, 27]
# 35 [25, 23]
